# %%
import pandas as pd
import numpy as np

# %%
essay_empathy_raw = pd.read_csv('./dataset/WASSA23_essay_level_with_labels_train.tsv', sep='\t', header=0)
article_raw = pd.read_csv('./dataset/articles_adobe_AMT.csv', header=0, index_col=0)

# %%
essay_empathy_raw
# Out:
#      conversation_id  article_id  \
# 0                  2          35
# 1                  3          35
# 2                  5          35
# 3                  6         213
# 4                  8         213
# ..               ...         ...
# 787              495         218
# 788              496         103
# 789              498         103
# 790              499         103
# 791              500         103
#
#                                                  essay   empathy  distress  \
# 0    It breaks my heart to see people living in tho...  6.714286  6.714286
# 1    I wonder why there aren't more people trying t...  5.857143  6.000000
# 2    After reading the article, you can't help but ...  1.000000  1.428571
# 3    It is so sad that someone who had such an amaz...  6.000000  6.857143
# 4    From reading the article, it looks like the wo...  6.000000  1.000000
# ..                                                 ...       ...       ...
# 787  I feel that this will become a national proble...  6.571429  6.714286
# 788  The whole situation is sketchy. The wavering r...  3.571429  6.428571
# 789  The death of a former aide to Russian Presiden...  5.428571  2.000000
# 790  Everything about Russia really freaks me out. ...  6.000000  6.000000
# 791  Whenever Russia and Putin are involved  I do n...  1.428571  5.428571
#
#      speaker_id gender education race age  ... personality_stability  \
# 0            30      1         6    3  37  ...                   6.0
# 1            19      1         6    2  32  ...                   4.5
# 2            17      1         6    1  29  ...                   7.0
# 3            16      2         5    1  28  ...                   3.5
# 4            30      1         6    3  37  ...                   6.0
# ..          ...    ...       ...  ...  ..  ...                   ...
# 787          30      1         6    3  37  ...                   6.0
# 788          16      2         5    1  28  ...                   3.5
# 789          43      2         6    1  33  ...                   7.0
# 790          53      2         3    1  27  ...                   6.0
# 791          30      1         6    3  37  ...                   6.0
#
#     iri_perspective_taking iri_personal_distress iri_fantasy  \
# 0                    4.857                   2.0       3.429
# 1                    3.429                 2.857       2.857
# 2                    4.643                2.0715       4.143
# 3                      5.0                 4.143       4.857
# 4                    4.857                   2.0       3.429
# ..                     ...                   ...         ...
# 787                  4.857                   2.0       3.429
# 788                    5.0                 4.143       4.857
# 789                  4.286                 1.286       3.857
# 790                    4.0                 2.286       3.571
# 791                  4.857                   2.0       3.429
#
#     iri_empathatic_concern speaker_number  split essay_id  \
# 0                      5.0              1  train        1
# 1                    2.714              1  train        2
# 2                    4.643              1  train        4
# 3                      5.0              1  train        5
# 4                      5.0              1  train        7
# ..                     ...            ...    ...      ...
# 787                    5.0              2  train      994
# 788                    5.0              2  train      995
# 789                    4.0              2  train      997
# 790                  3.714              2  train      998
# 791                    5.0              2  train      999
#
#                      idx       emotion
# 0         35_2_person1_1  Hope/Sadness
# 1         35_3_person1_2         Anger
# 2         35_5_person1_4       Sadness
# 3        213_6_person1_5       Sadness
# 4        213_8_person1_7       Neutral
# ..                   ...           ...
# 787  218_495_person2_494       Neutral
# 788  103_496_person2_495       Neutral
# 789  103_498_person2_497       Neutral
# 790  103_499_person2_498          Fear
# 791  103_500_person2_499       Sadness
#
# [792 rows x 25 columns]

# %%
article_raw.head()
# Out:
#                                                          text
# article_id
# 1           'Abhorrent' bottle attack on young Rangers fan...
# 2           'Afghan Girl' in iconic National Geographic ph...
# 3           'My whole family has been wiped out': Victims ...
# 4           'RHONY' STAR JULES WAINSTEIN Estranged Husband...
# 5           'Swam for their life': More survivors of Levia...

# %%
essay_empathy_raw.columns
# Out:
# Index(['conversation_id', 'article_id', 'essay', 'empathy', 'distress',
#        'speaker_id', 'gender', 'education', 'race', 'age', 'income',
#        'personality_conscientiousness', 'personality_openess',
#        'personality_extraversion', 'personality_agreeableness',
#        'personality_stability', 'iri_perspective_taking',
#        'iri_personal_distress', 'iri_fantasy', 'iri_empathatic_concern',
#        'speaker_number', 'split', 'essay_id', 'idx', 'emotion'],
#       dtype='object')

# %%
essay_empathy_raw.dtypes
# Out:
# conversation_id                    int64
# article_id                         int64
# essay                             object
# empathy                          float64
# distress                         float64
# speaker_id                         int64
# gender                            object
# education                         object
# race                              object
# age                               object
# income                            object
# personality_conscientiousness     object
# personality_openess               object
# personality_extraversion          object
# personality_agreeableness         object
# personality_stability             object
# iri_perspective_taking            object
# iri_personal_distress             object
# iri_fantasy                       object
# iri_empathatic_concern            object
# speaker_number                     int64
# split                             object
# essay_id                           int64
# idx                               object
# emotion                           object
# dtype: object

# %%
essay_empathy = essay_empathy_raw.copy()

# %%
essay_empathy.drop(columns=['speaker_id','split','essay_id','idx'], inplace=True)

# %%
essay_empathy
# Out:
#      conversation_id  article_id  \
# 0                  2          35
# 1                  3          35
# 2                  5          35
# 3                  6         213
# 4                  8         213
# ..               ...         ...
# 787              495         218
# 788              496         103
# 789              498         103
# 790              499         103
# 791              500         103
#
#                                                  essay   empathy  distress  \
# 0    It breaks my heart to see people living in tho...  6.714286  6.714286
# 1    I wonder why there aren't more people trying t...  5.857143  6.000000
# 2    After reading the article, you can't help but ...  1.000000  1.428571
# 3    It is so sad that someone who had such an amaz...  6.000000  6.857143
# 4    From reading the article, it looks like the wo...  6.000000  1.000000
# ..                                                 ...       ...       ...
# 787  I feel that this will become a national proble...  6.571429  6.714286
# 788  The whole situation is sketchy. The wavering r...  3.571429  6.428571
# 789  The death of a former aide to Russian Presiden...  5.428571  2.000000
# 790  Everything about Russia really freaks me out. ...  6.000000  6.000000
# 791  Whenever Russia and Putin are involved  I do n...  1.428571  5.428571
#
#     gender education race age  income  ... personality_openess  \
# 0        1         6    3  37   40000  ...                 5.5
# 1        1         6    2  32   35000  ...                 5.0
# 2        1         6    1  29   85000  ...                6.75
# 3        2         5    1  28   50000  ...                 6.0
# 4        1         6    3  37   40000  ...                 5.5
# ..     ...       ...  ...  ..     ...  ...                 ...
# 787      1         6    3  37   40000  ...                 5.5
# 788      2         5    1  28   50000  ...                 6.0
# 789      2         6    1  33  110000  ...                 4.5
# 790      2         3    1  27   25000  ...                 6.0
# 791      1         6    3  37   40000  ...                 5.5
#
#     personality_extraversion personality_agreeableness personality_stability  \
# 0                        1.0                       6.5                   6.0
# 1                        2.0                       5.5                   4.5
# 2                       6.75                      6.75                   7.0
# 3                        5.0                       4.5                   3.5
# 4                        1.0                       6.5                   6.0
# ..                       ...                       ...                   ...
# 787                      1.0                       6.5                   6.0
# 788                      5.0                       4.5                   3.5
# 789                      1.5                       7.0                   7.0
# 790                      6.0                       6.0                   6.0
# 791                      1.0                       6.5                   6.0
#
#     iri_perspective_taking iri_personal_distress iri_fantasy  \
# 0                    4.857                   2.0       3.429
# 1                    3.429                 2.857       2.857
# 2                    4.643                2.0715       4.143
# 3                      5.0                 4.143       4.857
# 4                    4.857                   2.0       3.429
# ..                     ...                   ...         ...
# 787                  4.857                   2.0       3.429
# 788                    5.0                 4.143       4.857
# 789                  4.286                 1.286       3.857
# 790                    4.0                 2.286       3.571
# 791                  4.857                   2.0       3.429
#
#     iri_empathatic_concern speaker_number       emotion
# 0                      5.0              1  Hope/Sadness
# 1                    2.714              1         Anger
# 2                    4.643              1       Sadness
# 3                      5.0              1       Sadness
# 4                      5.0              1       Neutral
# ..                     ...            ...           ...
# 787                    5.0              2       Neutral
# 788                    5.0              2       Neutral
# 789                    4.0              2       Neutral
# 790                  3.714              2          Fear
# 791                    5.0              2       Sadness
#
# [792 rows x 21 columns]

# %%
essay_empathy.columns
# Out:
# Index(['conversation_id', 'article_id', 'essay', 'empathy', 'distress',
#        'gender', 'education', 'race', 'age', 'income',
#        'personality_conscientiousness', 'personality_openess',
#        'personality_extraversion', 'personality_agreeableness',
#        'personality_stability', 'iri_perspective_taking',
#        'iri_personal_distress', 'iri_fantasy', 'iri_empathatic_concern',
#        'speaker_number', 'emotion'],
#       dtype='object')

# %%
numeric_columns = ['conversation_id', 'article_id', 'empathy', 'distress',
       'gender', 'education', 'race', 'age', 'income',
       'personality_conscientiousness', 'personality_openess',
       'personality_extraversion', 'personality_agreeableness',
       'personality_stability', 'iri_perspective_taking',
       'iri_personal_distress', 'iri_fantasy', 'iri_empathatic_concern',
       'speaker_number']

# %%
numeric_columns
# Out:
# ['conversation_id',
#  'article_id',
#  'empathy',
#  'distress',
#  'gender',
#  'education',
#  'race',
#  'age',
#  'income',
#  'personality_conscientiousness',
#  'personality_openess',
#  'personality_extraversion',
#  'personality_agreeableness',
#  'personality_stability',
#  'iri_perspective_taking',
#  'iri_personal_distress',
#  'iri_fantasy',
#  'iri_empathatic_concern',
#  'speaker_number']

# %%
essay_empathy = (essay_empathy.drop(columns=numeric_columns).join(essay_empathy[numeric_columns].apply(pd.to_numeric, errors='coerce'))) #converting non-numeric to null
essay_empathy.dropna(axis=0, inplace=True) #removing the rows having NA values

# %%
essay_empathy
# Out:
#                                                  essay       emotion  \
# 0    It breaks my heart to see people living in tho...  Hope/Sadness
# 1    I wonder why there aren't more people trying t...         Anger
# 2    After reading the article, you can't help but ...       Sadness
# 3    It is so sad that someone who had such an amaz...       Sadness
# 4    From reading the article, it looks like the wo...       Neutral
# ..                                                 ...           ...
# 787  I feel that this will become a national proble...       Neutral
# 788  The whole situation is sketchy. The wavering r...       Neutral
# 789  The death of a former aide to Russian Presiden...       Neutral
# 790  Everything about Russia really freaks me out. ...          Fear
# 791  Whenever Russia and Putin are involved  I do n...       Sadness
#
#      conversation_id  article_id   empathy  distress  gender  education  race  \
# 0                  2          35  6.714286  6.714286     1.0        6.0   3.0
# 1                  3          35  5.857143  6.000000     1.0        6.0   2.0
# 2                  5          35  1.000000  1.428571     1.0        6.0   1.0
# 3                  6         213  6.000000  6.857143     2.0        5.0   1.0
# 4                  8         213  6.000000  1.000000     1.0        6.0   3.0
# ..               ...         ...       ...       ...     ...        ...   ...
# 787              495         218  6.571429  6.714286     1.0        6.0   3.0
# 788              496         103  3.571429  6.428571     2.0        5.0   1.0
# 789              498         103  5.428571  2.000000     2.0        6.0   1.0
# 790              499         103  6.000000  6.000000     2.0        3.0   1.0
# 791              500         103  1.428571  5.428571     1.0        6.0   3.0
#
#       age  ...  personality_conscientiousness  personality_openess  \
# 0    37.0  ...                           7.00                 5.50
# 1    32.0  ...                           5.50                 5.00
# 2    29.0  ...                           6.75                 6.75
# 3    28.0  ...                           6.00                 6.00
# 4    37.0  ...                           7.00                 5.50
# ..    ...  ...                            ...                  ...
# 787  37.0  ...                           7.00                 5.50
# 788  28.0  ...                           6.00                 6.00
# 789  33.0  ...                           7.00                 4.50
# 790  27.0  ...                           6.00                 6.00
# 791  37.0  ...                           7.00                 5.50
#
#      personality_extraversion  personality_agreeableness  \
# 0                        1.00                       6.50
# 1                        2.00                       5.50
# 2                        6.75                       6.75
# 3                        5.00                       4.50
# 4                        1.00                       6.50
# ..                        ...                        ...
# 787                      1.00                       6.50
# 788                      5.00                       4.50
# 789                      1.50                       7.00
# 790                      6.00                       6.00
# 791                      1.00                       6.50
#
#      personality_stability  iri_perspective_taking  iri_personal_distress  \
# 0                      6.0                   4.857                 2.0000
# 1                      4.5                   3.429                 2.8570
# 2                      7.0                   4.643                 2.0715
# 3                      3.5                   5.000                 4.1430
# 4                      6.0                   4.857                 2.0000
# ..                     ...                     ...                    ...
# 787                    6.0                   4.857                 2.0000
# 788                    3.5                   5.000                 4.1430
# 789                    7.0                   4.286                 1.2860
# 790                    6.0                   4.000                 2.2860
# 791                    6.0                   4.857                 2.0000
#
#      iri_fantasy  iri_empathatic_concern  speaker_number
# 0          3.429                   5.000               1
# 1          2.857                   2.714               1
# 2          4.143                   4.643               1
# 3          4.857                   5.000               1
# 4          3.429                   5.000               1
# ..           ...                     ...             ...
# 787        3.429                   5.000               2
# 788        4.857                   5.000               2
# 789        3.857                   4.000               2
# 790        3.571                   3.714               2
# 791        3.429                   5.000               2
#
# [779 rows x 21 columns]

# %%
essay_empathy.isnull().any(axis=0)
# Out:
# essay                            False
# emotion                          False
# conversation_id                  False
# article_id                       False
# empathy                          False
# distress                         False
# gender                           False
# education                        False
# race                             False
# age                              False
# income                           False
# personality_conscientiousness    False
# personality_openess              False
# personality_extraversion         False
# personality_agreeableness        False
# personality_stability            False
# iri_perspective_taking           False
# iri_personal_distress            False
# iri_fantasy                      False
# iri_empathatic_concern           False
# speaker_number                   False
# dtype: bool

# %%
essay_empathy['emotion'].nunique()
# Out:
# 30

# %% [markdown]
# # Essay embeddings

# %%
essay_empathy['essay'] = essay_empathy['essay'].apply(lambda x: x.replace('\n', ' '))   #converting newlines (if any) to space

# %%
essay_empathy
# Out:
#                  article_id  \
# conversation_id
# 2                        35
# 3                        35
# 5                        35
# 6                       213
# 8                       213
# ...                     ...
# 495                     218
# 496                     103
# 498                     103
# 499                     103
# 500                     103
#
#                                                              essay   empathy  \
# conversation_id
# 2                It breaks my heart to see people living in tho...  6.714286
# 3                I wonder why there aren't more people trying t...  5.857143
# 5                After reading the article, you can't help but ...  1.000000
# 6                It is so sad that someone who had such an amaz...  6.000000
# 8                From reading the article, it looks like the wo...  6.000000
# ...                                                            ...       ...
# 495              I feel that this will become a national proble...  6.571429
# 496              The whole situation is sketchy. The wavering r...  3.571429
# 498              The death of a former aide to Russian Presiden...  5.428571
# 499              Everything about Russia really freaks me out. ...  6.000000
# 500              Whenever Russia and Putin are involved  I do n...  1.428571
#
#                  distress  speaker_id gender education race age  income  ...  \
# conversation_id                                                          ...
# 2                6.714286          30      1         6    3  37   40000  ...
# 3                6.000000          19      1         6    2  32   35000  ...
# 5                1.428571          17      1         6    1  29   85000  ...
# 6                6.857143          16      2         5    1  28   50000  ...
# 8                1.000000          30      1         6    3  37   40000  ...
# ...                   ...         ...    ...       ...  ...  ..     ...  ...
# 495              6.714286          30      1         6    3  37   40000  ...
# 496              6.428571          16      2         5    1  28   50000  ...
# 498              2.000000          43      2         6    1  33  110000  ...
# 499              6.000000          53      2         3    1  27   25000  ...
# 500              5.428571          30      1         6    3  37   40000  ...
#
#                 personality_stability iri_perspective_taking  \
# conversation_id
# 2                                 6.0                  4.857
# 3                                 4.5                  3.429
# 5                                 7.0                  4.643
# 6                                 3.5                    5.0
# 8                                 6.0                  4.857
# ...                               ...                    ...
# 495                               6.0                  4.857
# 496                               3.5                    5.0
# 498                               7.0                  4.286
# 499                               6.0                    4.0
# 500                               6.0                  4.857
#
#                 iri_personal_distress iri_fantasy iri_empathatic_concern  \
# conversation_id
# 2                                 2.0       3.429                    5.0
# 3                               2.857       2.857                  2.714
# 5                              2.0715       4.143                  4.643
# 6                               4.143       4.857                    5.0
# 8                                 2.0       3.429                    5.0
# ...                               ...         ...                    ...
# 495                               2.0       3.429                    5.0
# 496                             4.143       4.857                    5.0
# 498                             1.286       3.857                    4.0
# 499                             2.286       3.571                  3.714
# 500                               2.0       3.429                    5.0
#
#                 speaker_number  split essay_id                  idx  \
# conversation_id
# 2                            1  train        1       35_2_person1_1
# 3                            1  train        2       35_3_person1_2
# 5                            1  train        4       35_5_person1_4
# 6                            1  train        5      213_6_person1_5
# 8                            1  train        7      213_8_person1_7
# ...                        ...    ...      ...                  ...
# 495                          2  train      994  218_495_person2_494
# 496                          2  train      995  103_496_person2_495
# 498                          2  train      997  103_498_person2_497
# 499                          2  train      998  103_499_person2_498
# 500                          2  train      999  103_500_person2_499
#
#                       emotion
# conversation_id
# 2                Hope/Sadness
# 3                       Anger
# 5                     Sadness
# 6                     Sadness
# 8                     Neutral
# ...                       ...
# 495                   Neutral
# 496                   Neutral
# 498                   Neutral
# 499                      Fear
# 500                   Sadness
#
# [792 rows x 24 columns]

# %%
import fasttext
import fasttext.util
fasttext.util.download_model('en', if_exists='ignore')
ft = fasttext.load_model('cc.en.300.bin')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
essay_empathy['essay'] = essay_empathy['essay'].apply(lambda x: ft.get_sentence_vector(x))

# %%
essay_empathy
# Out:
#                  article_id  \
# conversation_id
# 2                        35
# 3                        35
# 5                        35
# 6                       213
# 8                       213
# ...                     ...
# 495                     218
# 496                     103
# 498                     103
# 499                     103
# 500                     103
#
#                                                              essay   empathy  \
# conversation_id
# 2                [-0.002007124, -0.002443538, 0.012782653, 0.05...  6.714286
# 3                [-0.02231253, -0.0023207075, 0.0041892305, 0.0...  5.857143
# 5                [-0.014148547, -0.0022076538, 0.0056234295, 0....  1.000000
# 6                [-0.0029112978, -0.024216617, 0.00064409646, 0...  6.000000
# 8                [-0.0049534906, 0.0014299279, 0.002449899, 0.0...  6.000000
# ...                                                            ...       ...
# 495              [-0.026065081, -0.00046226324, 0.0152548365, 0...  6.571429
# 496              [-0.018220283, -0.0012020977, 0.018358268, 0.0...  3.571429
# 498              [-0.019047705, 0.015028878, -0.000583674, 0.02...  5.428571
# 499              [-0.01293264, -0.010936364, 0.010585786, 0.047...  6.000000
# 500              [-0.006530351, 0.0085479785, 0.017405938, 0.05...  1.428571
#
#                  distress  speaker_id gender education race age  income  ...  \
# conversation_id                                                          ...
# 2                6.714286          30      1         6    3  37   40000  ...
# 3                6.000000          19      1         6    2  32   35000  ...
# 5                1.428571          17      1         6    1  29   85000  ...
# 6                6.857143          16      2         5    1  28   50000  ...
# 8                1.000000          30      1         6    3  37   40000  ...
# ...                   ...         ...    ...       ...  ...  ..     ...  ...
# 495              6.714286          30      1         6    3  37   40000  ...
# 496              6.428571          16      2         5    1  28   50000  ...
# 498              2.000000          43      2         6    1  33  110000  ...
# 499              6.000000          53      2         3    1  27   25000  ...
# 500              5.428571          30      1         6    3  37   40000  ...
#
#                 personality_stability iri_perspective_taking  \
# conversation_id
# 2                                 6.0                  4.857
# 3                                 4.5                  3.429
# 5                                 7.0                  4.643
# 6                                 3.5                    5.0
# 8                                 6.0                  4.857
# ...                               ...                    ...
# 495                               6.0                  4.857
# 496                               3.5                    5.0
# 498                               7.0                  4.286
# 499                               6.0                    4.0
# 500                               6.0                  4.857
#
#                 iri_personal_distress iri_fantasy iri_empathatic_concern  \
# conversation_id
# 2                                 2.0       3.429                    5.0
# 3                               2.857       2.857                  2.714
# 5                              2.0715       4.143                  4.643
# 6                               4.143       4.857                    5.0
# 8                                 2.0       3.429                    5.0
# ...                               ...         ...                    ...
# 495                               2.0       3.429                    5.0
# 496                             4.143       4.857                    5.0
# 498                             1.286       3.857                    4.0
# 499                             2.286       3.571                  3.714
# 500                               2.0       3.429                    5.0
#
#                 speaker_number  split essay_id                  idx  \
# conversation_id
# 2                            1  train        1       35_2_person1_1
# 3                            1  train        2       35_3_person1_2
# 5                            1  train        4       35_5_person1_4
# 6                            1  train        5      213_6_person1_5
# 8                            1  train        7      213_8_person1_7
# ...                        ...    ...      ...                  ...
# 495                          2  train      994  218_495_person2_494
# 496                          2  train      995  103_496_person2_495
# 498                          2  train      997  103_498_person2_497
# 499                          2  train      998  103_499_person2_498
# 500                          2  train      999  103_500_person2_499
#
#                       emotion
# conversation_id
# 2                Hope/Sadness
# 3                       Anger
# 5                     Sadness
# 6                     Sadness
# 8                     Neutral
# ...                       ...
# 495                   Neutral
# 496                   Neutral
# 498                   Neutral
# 499                      Fear
# 500                   Sadness
#
# [792 rows x 24 columns]
