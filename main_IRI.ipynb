# %%
import pandas as pd
import os

# %%
os.chdir("/home/573/rh2942/WASSA-2023-EMP") # changing dir for evaluation file

# %% [markdown]
# # Prediction

# %%
from main_methods import train_test_wo_acc

# %%
task='iri_perspective_taking'
train_test_wo_acc(task=task, lr=4.30e-05, batch_size=2, seed=65)
predictions_iri_perspective = pd.read_csv("./tmp/predictions_" + task + ".tsv", sep='\t', header=None)
# Out:
# iri_perspective_taking prediction
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/1974 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# Epoch 1: average loss = 0.7295303618325863
# Epoch 2: average loss = 0.18453547118688618
# Epoch 3: average loss = 0.06056255282273159
# Epoch 4: average loss = 0.02853252848048428
# Epoch 5: average loss = 0.017429934491155742
# Epoch 6: average loss = 0.023906753475486524
# Epoch 7: average loss = 0.024737295553012698
# Epoch 8: average loss = 0.010283238759099733
# Epoch 9: average loss = 0.03695141347306998
# Epoch 10: average loss = 0.033601567737956445
# Epoch 11: average loss = 0.003909939462147148
# Epoch 12: average loss = 0.0031529904810654033
# Epoch 13: average loss = 0.0024464783325505667
# Epoch 14: average loss = 0.002495594359750017
# Epoch 15: average loss = 0.01124141286787815
# Epoch 16: average loss = 0.004761094111652001
# Epoch 17: average loss = 0.003212481185896001
# Epoch 18: average loss = 0.0013534245211472328
# Epoch 19: average loss = 0.01068734417795006
# Epoch 20: average loss = 0.0032364809410802865
# Epoch 21: average loss = 0.0006810623591195358
# Epoch 22: average loss = 0.00114036270970232
# Epoch 23: average loss = 0.0008937026692229723
# Epoch 24: average loss = 0.0008619259097094381
# Epoch 25: average loss = 0.00048400846472804247
# Epoch 26: average loss = 0.005532411149502752
# Epoch 27: average loss = 0.0005503139855963131
# Epoch 28: average loss = 0.00013491379493573154
# Epoch 29: average loss = 9.412311139508582e-05
# Epoch 30: average loss = 7.69716309220425e-05
# Epoch 31: average loss = 5.68479208514613e-05
# Epoch 32: average loss = 5.085758679750556e-05
# Epoch 33: average loss = 3.8560033400442145e-05
# Epoch 34: average loss = 2.185795883148044e-05
# Epoch 35: average loss = 1.0848242959478755e-05

# %%
task='iri_personal_distress'
train_test_wo_acc(task=task, lr=4.38e-05, batch_size=7, seed=56)
predictions_iri_personal = pd.read_csv("./tmp/predictions_" + task + ".tsv", sep='\t', header=None)
# Out:
# iri_personal_distress prediction
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/1974 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Epoch 1: average loss = 0.6545927828006076
# Epoch 2: average loss = 0.17102052168986687
# Epoch 3: average loss = 0.0733211656870545
# Epoch 4: average loss = 0.04364346130627227
# Epoch 5: average loss = 0.016465728961514204
# Epoch 6: average loss = 0.006349611983338127
# Epoch 7: average loss = 0.0027467632700649094
# Epoch 8: average loss = 0.001961769362301537
# Epoch 9: average loss = 0.0014335079720449808
# Epoch 10: average loss = 0.0010438315146026806
# Epoch 11: average loss = 0.0010167899379421666
# Epoch 12: average loss = 0.0006790236020057967
# Epoch 13: average loss = 0.0006767350462317328
# Epoch 14: average loss = 0.0005598617921969754
# Epoch 22: average loss = 0.0010587664092130296
# Epoch 23: average loss = 0.0007662036761035482
# Epoch 24: average loss = 0.0005021599172323477
# Epoch 25: average loss = 0.00022527629824201778
# Epoch 26: average loss = 0.00014428905571342557
# Epoch 27: average loss = 0.00010707360358758623
# Epoch 28: average loss = 7.650611667837916e-05
# Epoch 29: average loss = 5.376739337497648e-05
# Epoch 30: average loss = 3.576229762400686e-05
# Epoch 31: average loss = 2.2581666379340837e-05
# Epoch 32: average loss = 1.184073530913525e-05
# Epoch 33: average loss = 8.27039276774124e-06
# Epoch 34: average loss = 5.465063817193065e-06
# Epoch 35: average loss = 4.082988333159021e-06

# %%
task='iri_fantasy'
train_test_wo_acc(task=task, lr=5.36e-05, batch_size=5, seed=13)
predictions_iri_fan = pd.read_csv("./tmp/predictions_" + task + ".tsv", sep='\t', header=None)
# Out:
# iri_fantasy prediction
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/1974 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Epoch 1: average loss = 0.5546702536766099
# Epoch 2: average loss = 0.10551266456907026
# Epoch 3: average loss = 0.037606968147358914
# Epoch 4: average loss = 0.026685550527188844
# Epoch 5: average loss = 0.03272013802739314
# Epoch 6: average loss = 0.014380109950765978
# Epoch 7: average loss = 0.011681719658832962
# Epoch 8: average loss = 0.00321673308068126
# Epoch 9: average loss = 0.0021043613189663754
# Epoch 10: average loss = 0.0011639459163268816
# Epoch 11: average loss = 0.0008694478053959895
# Epoch 12: average loss = 0.0026952861756157453
# Epoch 13: average loss = 0.00108901623221248
# Epoch 14: average loss = 0.0009435841605766114
# Epoch 15: average loss = 0.0008518874607794208
# Epoch 16: average loss = 0.0010198472085397078
# Epoch 17: average loss = 0.0011380182421368162
# Epoch 18: average loss = 0.001671995628078813
# Epoch 19: average loss = 0.00128274525824641
# Epoch 20: average loss = 0.0026097696776490966
# Epoch 21: average loss = 0.030552969573366257
# Epoch 22: average loss = 0.007633929726658676
# Epoch 23: average loss = 0.0015067168318913715
# Epoch 24: average loss = 0.0005144684349413839
# Epoch 25: average loss = 0.000263529555412431
# Epoch 26: average loss = 0.00018338331639416203
# Epoch 27: average loss = 0.00011364260539888659
# Epoch 28: average loss = 9.094029351044926e-05
# Epoch 29: average loss = 7.207146358027037e-05
# Epoch 30: average loss = 4.977249813405366e-05
# Epoch 31: average loss = 4.1231175245390857e-05
# Epoch 32: average loss = 3.3234408211148e-05
# Epoch 33: average loss = 2.6294048675740497e-05
# Epoch 34: average loss = 2.1030861230025914e-05
# Epoch 35: average loss = 1.6561976399517807e-05

# %%
task='iri_empathatic_concern'
train_test_wo_acc(task=task, lr=4.92e-05, batch_size=5, seed=1)
predictions_iri_empath = pd.read_csv("./tmp/predictions_" + task + ".tsv", sep='\t', header=None)
# Out:
# iri_empathatic_concern prediction
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/1974 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Epoch 1: average loss = 0.7746236254873721
# Epoch 2: average loss = 0.1217168495804661
# Epoch 3: average loss = 0.04607045137245338
# Epoch 4: average loss = 0.03476528126224757
# Epoch 5: average loss = 0.020067666858343314
# Epoch 6: average loss = 0.007965514274773444
# Epoch 7: average loss = 0.00404796852545829
# Epoch 8: average loss = 0.00276328472214636
# Epoch 9: average loss = 0.007158666750834941
# Epoch 10: average loss = 0.03886531776401562
# Epoch 11: average loss = 0.03549429937206869
# Epoch 12: average loss = 0.010426462002509698
# Epoch 13: average loss = 0.005141565512701474
# Epoch 14: average loss = 0.0028758913652877074
# Epoch 15: average loss = 0.0012109560915011075
# Epoch 16: average loss = 0.0007567288793866225
# Epoch 17: average loss = 0.00046789292309192286
# Epoch 18: average loss = 0.00033160406912452635
# Epoch 19: average loss = 0.0004079622268812883
# Epoch 20: average loss = 0.000533917074854695
# Epoch 21: average loss = 0.0005877699425605275
# Epoch 22: average loss = 0.0005327219759893995
# Epoch 23: average loss = 0.0004973388228480169
# Epoch 24: average loss = 0.0004250504516998654
# Epoch 25: average loss = 0.0004486443716929518
# Epoch 26: average loss = 0.00036345482924763376
# Epoch 27: average loss = 0.00034866955266473187
# Epoch 28: average loss = 0.0003202093188266662
# Epoch 29: average loss = 0.0003895932531657861
# Epoch 30: average loss = 0.00019633553065748948
# Epoch 31: average loss = 7.689372839736221e-05
# Epoch 32: average loss = 4.342049502311862e-05
# Epoch 33: average loss = 2.625579392145747e-05
# Epoch 34: average loss = 1.1148206078239208e-05
# Epoch 35: average loss = 6.570942495268585e-06

# %%
predictions_IRI = pd.concat([predictions_iri_perspective, predictions_iri_personal, predictions_iri_fan, predictions_iri_empath], axis=1)

predictions_IRI.to_csv("./prediction/predictions_IRI.tsv", sep='\t', header=False, index=False)

# %% [markdown]
# # Just checking dev set performance

# %%
from evaluation import pearsonr

# %%
# Just checking the dev set performance
gold_dev = pd.read_csv('./dataset/dev/goldstandard_dev.tsv', sep='\t', header=None) # no header
# predictions_IRI= pd.read_csv("./prediction/predictions_IRI.tsv", sep='\t', header=None)

print(f"iri_perspective: {pearsonr(gold_dev.loc[:,8].tolist(), predictions_IRI.loc[:,0].tolist())}")
print(f"iri_personal: {pearsonr(gold_dev.loc[:,9].tolist(), predictions_IRI.loc[:,1].tolist())}")
print(f"iri_fan: {pearsonr(gold_dev.loc[:,10].tolist(), predictions_IRI.loc[:,2].tolist())}")
print(f"iri_empath: {pearsonr(gold_dev.loc[:,11].tolist(), predictions_IRI.loc[:,3].tolist())}")

# %% [markdown]
# # Hyperparam tuning

# %%
from hyperparam_tuner import optuna_tuner

# %%
tasks = [
    'iri_perspective_taking',
    'iri_personal_distress',
    'iri_fantasy',
    'iri_empathatic_concern'
]

for task in tasks:
    optuna_tuner(task=task)
